# %%
import pandas as pd # aqui importamos pandas

# %%
df1 = pd.DataFrame({   # aqui creamos un data frame con un diccionario
    "name": ["Jhion", "Frank", "Aquiles"],
    "Addres": ["Nueva york", "Leon 220","Grecia"],
    "edad" : [28, 28,32]
})

# %%
print (df1)
# Out:
#       name      Addres  edad
# 0    Jhion  Nueva york    28
# 1    Frank    Leon 220    28
# 2  Aquiles      Grecia    32

# %%
df1.index # es para ver los indices de info que tiene y te explica donde inicia 
          #y donde termina ademas de cuantos en cuantos va
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df1.loc[1] # esta funion es para imprimir una linea y te muestra kla info dentro de las llaves pones 
           # el indice que quieres ver o mostrar
# Out:
# name         Frank
# Addres    Leon 220
# edad            28
# Name: 1, dtype: object

# %%
df2 = pd.DataFrame([
    ["Jhon", "Americas 215", 28],          #esto es otro metodo de dataframe con listas
    ["Tarzan", "AFRICA OCCIDENTAL", 22],   #se acaba la lista padre y depues se agrega una "," y despues se 
    ["Paco", "JAPAN", 28]                #asignan las columnas
],
columns = ["name", "address", "age"])

# %%
print(df2)
# Out:
#      name            address  age
# 0    Jhon       Americas 215   28
# 1  Tarzan  AFRICA OCCIDENTAL   22
# 2    Paco              JAPAN   28

# %%
df3 = pd.read_csv("datasets/imdb.csv") # esto es para mostrar una csv y se genera un data frame en automatico 
                                 # dentro del parentesis se pone la ruta del archivo junto con su nombre

# %%
df3.head() #es para mostar el encabezado del data frame te muestra los 5 primeros valores
# Out:
#    id                                       name   genre  year imdb_rating
# 0   1                                     Avatar  action  2009         7.9
# 1   2                             Jurassic World  action  2015         7.3
# 2   3                               The Avengers  action  2012         8.1
# 3   4                            The Dark Knight  action  2008         9.0
# 4   5  Star Wars: Episode I - The Phantom Menace  action  1999         6.6

# %%
df3.info()   # te muestra distintas metricas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           220 non-null    int64
#  1   name         220 non-null    object
#  2   genre        220 non-null    object
#  3   year         220 non-null    int64
#  4   imdb_rating  220 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 8.7+ KB

# %%
df4 = pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})

# %%
df4
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
dfacustomers= pd.DataFrame([
    ["Rebecca erikson" , 35],
    ["Francisco", 25],
    ["Jhon 117" ,33],
],
columns = ["Name", "Age"])

# %%
dfacustomers["Age"] # es para hacer la consulta de una columna ocn el metodo de diccionario
# Out:
# 0    35
# 1    25
# 2    33
# Name: Age, dtype: int64

# %%
dfacustomers.Age
# Out:
# 0    35
# 1    25
# 2    33
# Name: Age, dtype: int64

# %%
name = df3.name # la consulta se le puede asiganar a una variable

# %%
name # aqui llame a la variable
# Out:
# 0                                         Avatar
# 1                                 Jurassic World
# 2                                   The Avengers
# 3                                The Dark Knight
# 4      Star Wars: Episode I - The Phantom Menace
#                          ...
# 215                                     Hannibal
# 216                          Catch Me If You Can
# 217                                    Big Daddy
# 218                                        Se7en
# 219                                        Seven
# Name: name, Length: 220, dtype: object

# %%
# vamos a crear una serie desde 0

# %%
clinica = pd.Series([100 , 50 , 18, 20, "paco"])
print(clinica)
# Out:
# 0     100
# 1      50
# 2      18
# 3      20
# 4    paco
# dtype: object

# %%
print(type(clinica))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# para hacer una seleccion multiple se usa el metodo de listasA

# %%
seleccionmultipledeColumnas = df3[["year","genre"]]
print(seleccionmultipledeColumnas)
# Out:
#      year   genre
# 0    2009  action
# 1    2015  action
# 2    2012  action
# 3    2008  action
# 4    1999  action
# ..    ...     ...
# 215  2001   drama
# 216  2002   drama
# 217  1999   drama
# 218  1995   drama
# 219  1979   drama
#
# [220 rows x 2 columns]

# %%
avengers = df3.iloc[2]
print(avengers)
# Out:
# id                        3
# name           The Avengers
# genre                action
# year                   2012
# imdb_rating             8.1
# Name: 2, dtype: object

# %%
# para seleccion multiple de lineas la sintaxis es asi
#df.iloc[inicio:final - 1 ]

# %%
df3.iloc[0: 20]
# Out:
#     id                                          name   genre  year imdb_rating
# 0    1                                        Avatar  action  2009         7.9
# 1    2                                Jurassic World  action  2015         7.3
# 2    3                                  The Avengers  action  2012         8.1
# 3    4                               The Dark Knight  action  2008         9.0
# 4    5     Star Wars: Episode I - The Phantom Menace  action  1999         6.6
# 5    6                                     Star Wars  action  1977         8.7
# 6    7                       Avengers: Age of Ultron  action  2015         7.9
# 7    8                         The Dark Knight Rises  action  2012         8.5
# 8    9     Pirates of the Caribbean: Dead Mans Chest  action  2006         7.3
# 9   10                                    Iron Man 3  action  2013         7.3
# 10  11                                    Spider-Man  action  2002        7.3v
# ...

# %%
df3[df3.genre == "horror"]
# Out:
#       id                                               name   genre  year  \
# 97    98                                        World War Z  horror  2013
# 98    99                                  What Lies Beneath  horror  2000
# 99   100                                           Gremlins  horror  1984
# 100  101                            The Blair Witch Project  horror  1999
# 101  102                                      The Conjuring  horror  2013
# 102  103                                           The Ring  horror  2002
# 103  104                                         The Grudge  horror  2004
# 104  105                                Paranormal Activity  horror  2007
# 105  106  Interview with the Vampire: The Vampire Chroni...  horror  1994
# 106  107                              Paranormal Activity 3  horror  2011
# 107  108                                             Scream  horror  1996
# 108  109                                             Jaws 2  horror  1978
# ...

# %%
df3[df3.genre != "horror"]
# Out:
#       id                                       name   genre  year imdb_rating
# 0      1                                     Avatar  action  2009         7.9
# 1      2                             Jurassic World  action  2015         7.3
# 2      3                               The Avengers  action  2012         8.1
# 3      4                            The Dark Knight  action  2008         9.0
# 4      5  Star Wars: Episode I - The Phantom Menace  action  1999         6.6
# ..   ...                                        ...     ...   ...         ...
# 215  216                                   Hannibal   drama  2001         6.7
# 216  217                        Catch Me If You Can   drama  2002         8.0
# 217  218                                  Big Daddy   drama  1999         6.4
# 218  219                                      Se7en   drama  1995         8.6
# 219  220                                      Seven   drama  1979         6.1
#
# [171 rows x 5 columns]

# %%
condicional or se expresa con este simbolo |

# %%
df3[(df3.year > 2014) | (df3.genre == "action")]
# Out:
#       id                                               name    genre  year  \
# 0      1                                             Avatar   action  2009
# 1      2                                     Jurassic World   action  2015
# 2      3                                       The Avengers   action  2012
# 3      4                                    The Dark Knight   action  2008
# 4      5          Star Wars: Episode I - The Phantom Menace   action  1999
# 5      6                                          Star Wars   action  1977
# 6      7                            Avengers: Age of Ultron   action  2015
# 7      8                              The Dark Knight Rises   action  2012
# 8      9          Pirates of the Caribbean: Dead Mans Chest   action  2006
# 9     10                                         Iron Man 3   action  2013
# 10    11                                         Spider-Man   action  2002
# ...

# %%
df3[(df3.year > 2014) & (df3.genre == "comedy")]
# Out:
#     id        name   genre  year imdb_rating
# 55  56  Inside Out  comedy  2015         8.6
# 57  58     Minions  comedy  2015         6.7

# %%
# para seleccionar varias filas pero con filtros en especifico se hace asi:
myseleccion = df3[df3.name.isin(["Star Wars", "Blade", "one piece"])]

print(myseleccion)
# Out:
#       id       name   genre  year imdb_rating
# 5      6  Star Wars  action  1977         8.7
# 137  138      Blade  horror  1998         7.1

# %%
# PARA RECETEAR EL INDICE SE USA EL METODO .reset_index()

# %%
myseleccion.reset_index()
# Out:
#    index   id       name   genre  year imdb_rating
# 0      5    6  Star Wars  action  1977         8.7
# 1    137  138      Blade  horror  1998         7.1

# %%
# para despues borrar el indice index

# %%
myseleccion.reset_index(drop=True) #DENTRO DEL PARAMETRO DE RESET SE USA EL COMANDO DROP
# Out:
#     id       name   genre  year imdb_rating
# 0    6  Star Wars  action  1977         8.7
# 1  138      Blade  horror  1998         7.1

# %%
# modificando data frame desde pandas agregar una nueva columna

# %%
import pandas as pd
